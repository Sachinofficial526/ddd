# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
ds=pd.read_csv("C:\\Users\\Administrator\\Desktop\\Admission_predict.csv")

# %%
ds
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
ds.shape

# %%
ds.info()

# %%
newdataset=ds.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research'],axis=1)

# %%
newdataset
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 395        324              0.82
# 396        325              0.84
# 397        330              0.91
# 398        312              0.67
# 399        333              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)

# %%
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE Score')
pt.ylabel('CHA')
pt.title('linear reg')
pt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
X_train.shape
# Out:
# (280, 1)

# %%
pip install scikit_learn

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[298],
#        [308],
#        [330],
#        [312],
#        [290],
#        [331],
#        [328],
#        [318],
#        [318],
#        [293],
#        [334],
#        [317],
#        [327],
#        [296],
#        [324],
#        [312],
#        [328],
#        [316],
#        [299],
#        [319],
#        [329],
#        [317],
#        [300],
#        [311],
#        [324],
#        [317],
#        [314],
#        [328],
#        [326],
#        [299],
#        [327],
#        [335],
#        [313],
#        [301],
#        [330],
#        [312],
#        [322],
#        [323],
#        [311],
#        [305],
#        [317],
#        [323],
#        [340],
#        [303],
#        [318],
#        [331],
#        [319],
#        [331],
#        [319],
#        [307],
#        [313],
#        [312],
#        [317],
#        [318],
#        [313],
#        [324],
#        [331],
#        [329],
#        [317],
#        [325],
#        [305],
#        [314],
# ...

# %%
Y_train
# Out:
# array([[0.34],
#        [0.71],
#        [0.91],
#        [0.69],
#        [0.47],
#        [0.92],
#        [0.94],
#        [0.71],
#        [0.74],
#        [0.64],
#        [0.93],
#        [0.77],
#        [0.61],
#        [0.6 ],
#        [0.84],
#        [0.64],
#        [0.84],
#        [0.77],
#        [0.63],
#        [0.65],
#        [0.81],
#        [0.84],
#        [0.65],
#        [0.59],
#        [0.7 ],
#        [0.57],
#        [0.7 ],
#        [0.81],
#        [0.88],
#        [0.56],
#        [0.8 ],
#        [0.94],
#        [0.79],
#        [0.62],
#        [0.93],
#        [0.76],
#        [0.78],
#        [0.85],
#        [0.7 ],
#        [0.71],
#        [0.8 ],
#        [0.79],
#        [0.9 ],
#        [0.56],
#        [0.67],
#        [0.94],
#        [0.74],
#        [0.86],
#        [0.76],
#        [0.47],
#        [0.64],
#        [0.81],
#        [0.73],
#        [0.71],
#        [0.73],
#        [0.89],
#        [0.93],
#        [0.86],
# ...

# %%
lm.fit(X_train , Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = lm.predict(X_test)

# %%
Y_predict
# Out:
# array([[0.64896123],
#        [0.63882912],
#        [0.82120702],
#        [0.61856491],
#        [0.71988597],
#        [0.64896123],
#        [0.67935754],
#        [0.67935754],
#        [0.88199965],
#        [0.87186755],
#        [0.55777228],
#        [0.89213176],
#        [0.76041439],
#        [0.57803649],
#        [0.84147123],
#        [0.66922544],
#        [0.67935754],
#        [0.85160334],
#        [0.70975386],
#        [0.68948965],
#        [0.85160334],
#        [0.83133912],
#        [0.56790439],
#        [0.50711175],
#        [0.76041439],
#        [0.56790439],
#        [0.51724386],
#        [0.69962176],
#        [0.92252807],
#        [0.69962176],
#        [0.67935754],
#        [0.7908107 ],
#        [0.67935754],
#        [0.51724386],
#        [0.81107491],
#        [0.83133912],
#        [0.74015018],
#        [0.7908107 ],
#        [0.62869702],
#        [0.89213176],
#        [0.7806786 ],
#        [0.69962176],
#        [0.77054649],
# ...

# %%
comp=pd.DataFrame(X_test,columns=['GEH'])

# %%
comp
# Out:
#      GEH
# 0    309
# 1    308
# 2    326
# 3    306
# 4    316
# ..   ...
# 115  322
# 116  331
# 117  327
# 118  310
# 119  305
#
# [120 rows x 1 columns]

# %%
comp["AVLDATA"]=Y_test

# %%
comp
# Out:
#      GEH  AVLDATA
# 0    309     0.71
# 1    308     0.70
# 2    326     0.79
# 3    306     0.73
# 4    316     0.72
# ..   ...      ...
# 115  322     0.91
# 116  331     0.90
# 117  327     0.78
# 118  310     0.70
# 119  305     0.59
#
# [120 rows x 2 columns]

# %%
comp["PRDDATA"]=Y_predict

# %%
comp
# Out:
#      GEH  AVLDATA   PRDDATA
# 0    309     0.71  0.648961
# 1    308     0.70  0.638829
# 2    326     0.79  0.821207
# 3    306     0.73  0.618565
# 4    316     0.72  0.719886
# ..   ...      ...       ...
# 115  322     0.91  0.780679
# 116  331     0.90  0.871868
# 117  327     0.78  0.831339
# 118  310     0.70  0.659093
# 119  305     0.59  0.608433
#
# [120 rows x 3 columns]

# %%
pt.scatter (x,y,color='red')
pt.plot(X_test,Y_predict,color='blue')
pt.xlabel('GRE score')
pt.ylabel('linear reg')
pt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(Y_test,Y_predict)
# Out:
# 0.007826045775649491

# %%
mean_absolute_error

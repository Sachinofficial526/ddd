# %%
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
ds=pd.read_csv("C:\\Users\\aedpu\\OneDrive\\Documents\\sachin\\Admission_predict.csv")

# %%
ds
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
ds.shape
# Out:
# (400, 9)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
newdataset=ds.drop(['Serial No.','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research'],axis=1)

# %%
newdataset
# Out:
#      GRE Score  Chance of Admit
# 0          337              0.92
# 1          324              0.76
# 2          316              0.72
# 3          322              0.80
# 4          314              0.65
# ..         ...               ...
# 395        324              0.82
# 396        325              0.84
# 397        330              0.91
# 398        312              0.67
# 399        333              0.95
#
# [400 rows x 2 columns]

# %%
x=newdataset.iloc[:,0].values.reshape(-1,1)

# %%
y=newdataset.iloc[:,1].values.reshape(-1,1)

# %%
y
# Out:
# array([[0.92],
#        [0.76],
#        [0.72],
#        [0.8 ],
#        [0.65],
#        [0.9 ],
#        [0.75],
#        [0.68],
#        [0.5 ],
#        [0.45],
#        [0.52],
#        [0.84],
#        [0.78],
#        [0.62],
#        [0.61],
#        [0.54],
#        [0.66],
#        [0.65],
#        [0.63],
#        [0.62],
#        [0.64],
#        [0.7 ],
#        [0.94],
#        [0.95],
#        [0.97],
#        [0.94],
#        [0.76],
#        [0.44],
#        [0.46],
#        [0.54],
#        [0.65],
#        [0.74],
#        [0.91],
#        [0.9 ],
#        [0.94],
#        [0.88],
#        [0.64],
#        [0.58],
#        [0.52],
#        [0.48],
#        [0.46],
#        [0.49],
#        [0.53],
#        [0.87],
#        [0.91],
#        [0.88],
#        [0.86],
#        [0.89],
#        [0.82],
#        [0.78],
#        [0.76],
#        [0.56],
#        [0.78],
#        [0.72],
#        [0.7 ],
#        [0.64],
#        [0.64],
#        [0.46],
# ...

# %%
x
# Out:
# array([[337],
#        [324],
#        [316],
#        [322],
#        [314],
#        [330],
#        [321],
#        [308],
#        [302],
#        [323],
#        [325],
#        [327],
#        [328],
#        [307],
#        [311],
#        [314],
#        [317],
#        [319],
#        [318],
#        [303],
#        [312],
#        [325],
#        [328],
#        [334],
#        [336],
#        [340],
#        [322],
#        [298],
#        [295],
#        [310],
#        [300],
#        [327],
#        [338],
#        [340],
#        [331],
#        [320],
#        [299],
#        [300],
#        [304],
#        [307],
#        [308],
#        [316],
#        [313],
#        [332],
#        [326],
#        [322],
#        [329],
#        [339],
#        [321],
#        [327],
#        [313],
#        [312],
#        [334],
#        [324],
#        [322],
#        [320],
#        [316],
#        [298],
#        [300],
#        [311],
#        [309],
#        [307],
# ...

# %%
pt.scatter(x,y)
pt.xlabel('GRE Score')
pt.ylabel('CHA')
pt.tittle('linear reg')
pt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3504\1713710636.py in <module>
#       2 pt.xlabel('GRE Score')
#       3 pt.ylabel('CHA')
# ----> 4 pt.tittle('linear reg')
#       5 pt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tittle'

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_train=train_test_split(x,y,train_size=0.7,random_state=0)

# %%
x_train.shape
# Out:
# (280, 1)

# %%
pip install scikit_learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

# %%
ln=LinearRegression

# %%
ln
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
x_train
# Out:
# array([[298],
#        [308],
#        [330],
#        [312],
#        [290],
#        [331],
#        [328],
#        [318],
#        [318],
#        [293],
#        [334],
#        [317],
#        [327],
#        [296],
#        [324],
#        [312],
#        [328],
#        [316],
#        [299],
#        [319],
#        [329],
#        [317],
#        [300],
#        [311],
#        [324],
#        [317],
#        [314],
#        [328],
#        [326],
#        [299],
#        [327],
#        [335],
#        [313],
#        [301],
#        [330],
#        [312],
#        [322],
#        [323],
#        [311],
#        [305],
#        [317],
#        [323],
#        [340],
#        [303],
#        [318],
#        [331],
#        [319],
#        [331],
#        [319],
#        [307],
#        [313],
#        [312],
#        [317],
#        [318],
#        [313],
#        [324],
#        [331],
#        [329],
#        [317],
#        [325],
#        [305],
#        [314],
# ...

# %%
y_train
# Out:
# array([[0.71],
#        [0.7 ],
#        [0.79],
#        [0.73],
#        [0.72],
#        [0.48],
#        [0.77],
#        [0.71],
#        [0.9 ],
#        [0.94],
#        [0.58],
#        [0.89],
#        [0.72],
#        [0.57],
#        [0.78],
#        [0.42],
#        [0.64],
#        [0.84],
#        [0.63],
#        [0.72],
#        [0.9 ],
#        [0.83],
#        [0.57],
#        [0.47],
#        [0.85],
#        [0.67],
#        [0.44],
#        [0.54],
#        [0.92],
#        [0.62],
#        [0.68],
#        [0.73],
#        [0.73],
#        [0.61],
#        [0.55],
#        [0.74],
#        [0.64],
#        [0.89],
#        [0.73],
#        [0.95],
#        [0.71],
#        [0.72],
#        [0.75],
#        [0.76],
#        [0.86],
#        [0.7 ],
#        [0.39],
#        [0.79],
#        [0.61],
#        [0.64],
#        [0.71],
#        [0.8 ],
#        [0.61],
#        [0.89],
#        [0.68],
#        [0.79],
#        [0.78],
#        [0.52],
# ...

# %%
ln.fit (x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3504\1576082017.py in <module>
# ----> 1 ln.fit (x_train,y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'

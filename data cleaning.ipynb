# %%
import pandas as pd

# %%
salary_data=pd.DataFrame({'salary':[19000,31000,67000,78000],'Range':['low','mid','high','high']})

# %%
salary_data
# Out:
#    salary Range
# 0   19000   low
# 1   31000   mid
# 2   67000  high
# 3   78000  high

# %%
a=salary_data.salary.map({19000:4,31000:3,67000:2,78000:1})

# %%
a
# Out:
# 0    4
# 1    3
# 2    2
# 3    1
# Name: salary, dtype: int64

# %% [markdown]
# # normalization

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
normalization_df=pd.DataFrame({'x':np.random.randint(-100,100,1000),'y':np.random.randint(-80,80,1000),'z':np.random.randint(-600,500,1000)})

# %%
normalization_df
# Out:
#       x   y    z
# 0    86 -74 -169
# 1    -5  39  196
# 2   -15  57 -363
# 3    79  -6  133
# 4   -79 -50 -244
# ..   ..  ..  ...
# 995  17  59 -327
# 996 -23 -56  447
# 997  67 -74 -567
# 998 -19  69  380
# 999 -54 -68 -210
#
# [1000 rows x 3 columns]

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(normalization_df.x,normalization_df.y,normalization_df.z)
plt.figure()

# %%
from sklearn.preprocessing import Normalizer

# %%
normal=Normalizer()

# %%
normalization_df=normal.fit_transform(normalization_df)

# %%
normalization_df
# Out:
# array([[ 0.42249859, -0.3635453 , -0.83025885],
#        [-0.02501188,  0.19509269,  0.98046583],
#        [-0.04078814,  0.15499492, -0.9870729 ],
#        ...,
#        [ 0.11637593, -0.12853461, -0.98485303],
#        [-0.04913614,  0.17844178,  0.98272284],
#        [-0.23762966, -0.29923735, -0.92411534]])

# %%
norm_df=pd.DataFrame(normalization_df,columns=['x1','x2','x3'])

# %%
norm_df
# Out:
#            x1        x2        x3
# 0    0.422499 -0.363545 -0.830259
# 1   -0.025012  0.195093  0.980466
# 2   -0.040788  0.154995 -0.987073
# 3    0.510304 -0.038757  0.859120
# 4   -0.302336 -0.191352 -0.933797
# ..        ...       ...       ...
# 995  0.051095  0.177329 -0.982824
# 996 -0.050989 -0.124146  0.990953
# 997  0.116376 -0.128535 -0.984853
# 998 -0.049136  0.178442  0.982723
# 999 -0.237630 -0.299237 -0.924115
#
# [1000 rows x 3 columns]

# %%
ax=plt.axes(projection='3d')
ax.scatter3D(norm_df.x1,norm_df.x2,norm_df.x3)
plt.figure()

# %% [markdown]
# # data sorting

# %%
data=[16,21,15,7,8,24,9,1,30,10,25,13,26,11,2,5,20,28,18,3]

# %%
data.reverse()
print(data)
# Out:
# [30, 28, 26, 25, 24, 21, 20, 18, 16, 15, 13, 11, 10, 9, 8, 7, 5, 3, 2, 1]

# %% [markdown]
# # missing values

# %%
import numpy as np
import pandas as pd

# %%
data={'first score':[100,90,np.nan,95],'second score':[30,45,56,np.nan],'third score':[40,80,np.nan,98]}

# %%
scores=pd.DataFrame(data)

# %%
scores
# Out:
#    first score  second score  third score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         80.0
# 2          NaN          56.0          NaN
# 3         95.0           NaN         98.0

# %%
scores.isnull()
# Out:
#    first score  second score  third score
# 0        False         False        False
# 1        False         False        False
# 2         True         False         True
# 3        False          True        False

# %%
scores.isnull().sum()
# Out:
# first score     1
# second score    1
# third score     1
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='median')

# %%
imputer.fit(scores)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.transform(scores)
# Out:
# array([[100.        ,  30.        ,  40.        ],
#        [ 90.        ,  45.        ,  80.        ],
#        [ 95.        ,  56.        ,  72.66666667],
#        [ 95.        ,  43.66666667,  98.        ]])
